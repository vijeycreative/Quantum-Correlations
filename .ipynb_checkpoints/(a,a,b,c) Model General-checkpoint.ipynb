# %%
import math
import itertools
import numpy as np
import multiprocessing
from multiprocessing import Process, Pool, Array
from tqdm import tqdm
import time
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
def probDist(a,b,c):
    pArr = np.array([[a,b,a,b],
                 [b,a,a,b],
                 [b,a,b,a],
                 [a,b,b,a]])
    return pArr

# %%
def mutualInfo(p):
    return 2 - ((1-2*p)*(1-math.log2(1-2*p))-2*p*math.log2(p))

# %%
viol = []
distribution = []
arrSettings = []
MIs = []
maximalViol = []
def calculateViolation(arr):
    x = np.arange(0.01, 0.25, 0.01)
    for p in x:
        pArr = probDist(p)
        xy = 0
        xY = 0
        Xy = 0
        XY = 0
        for i in range(0, arr.shape[1]):
            xy += arr[0,i]*arr[2,i]*pArr[0,i]
            xY += arr[0,i]*arr[3,i]*pArr[1,i]
            Xy += arr[1,i]*arr[2,i]*pArr[2,i]
            XY += arr[1,i]*arr[3,i]*pArr[3,i]
        E = xy + xY +Xy - XY
        MI = mutualInfo(p)
        viol.append(abs(2-abs(E)))
        distribution.append(p)
        MIs.append(MI)
        pbar.update(1)  
        if(abs(2-abs(E)) == 2.0 and MI < 0.01):
            #print("P = ",p, " Setting = ", arr)
            maximalViol.append(arr)

# %%
values = [-1,1]
seq = itertools.product(values, repeat=16)
pbar = tqdm(total=1572864)
for s in seq:
    # convert to numpy array and reshape to 4x4
    settingArray = np.fromiter(s, np.int8).reshape(4, 4)
    calculateViolation(settingArray)
# Out:
# 100%|██████████| 1572864/1572864 [01:21<00:00, 23609.24it/s]

# %%
plt.rcParams['agg.path.chunksize'] = 10000
plt.rcParams["figure.figsize"] = (12,8)

# %%
sns.scatterplot(x=viol, y=MIs, hue=distribution)

# %%
plt.plot(viol,MIs)

# %%
data = []
for i in range(len(viol)):
    data[i] = (viol[i], MIs[i])
data
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-e5875500d205> in <module>
#       1 data = []
#       2 for i in range(len(viol)):
# ----> 3     data[i] = (viol[i], MIs[i])
#       4 data
#
# IndexError: list assignment index out of range

# %%
plt.plot(viol,MIs)

# %%
len(maximalViol)
# Out:
# 18432
